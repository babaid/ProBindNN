# %%
from src.make_dataset import make_dataset
# Out:
# c:\ProgramData\Miniconda3\envs\bioml2\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# To use the Graphein submodule graphein.protein.features.sequence.embeddings, you need to install: biovec
# biovec cannot be installed via conda
# To use the Graphein submodule graphein.protein.visualisation, you need to install: pytorch3d
# To do so, use the following command: conda install -c pytorch3d pytorch3d
# [08/13/22 17:17:14] WARNING  To use the Graphein submodule graphein.protein.meshes, you need to        ]8;id=144850;file://c:\ProgramData\Miniconda3\envs\bioml2\lib\site-packages\graphein\protein\meshes.py\meshes.py]8;;\:]8;id=191242;file://c:\ProgramData\Miniconda3\envs\bioml2\lib\site-packages\graphein\protein\meshes.py#29\29]8;;\
#                              install: pytorch3d
#                              To do so, use the following command: conda install -c pytorch3d pytorch3d

# %%
make_dataset(index_xlsx="./index.xlsx", root="dataset12aa")
# Out:
# 4943it [00:20, 239.86it/s]
# Time needed for creating the mutations: 20.61468505859375s
# 0it [00:00, ?it/s]
# Protein:  1cse Mutation:  LI38G
# Output()
# Extracting relevant residues
# I 38
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
from graphein.protein.edges.atomic import add_atomic_edges, add_bond_order, add_ring_status
